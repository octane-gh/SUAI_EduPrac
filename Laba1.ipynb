# %% [markdown]
# <a href="https://colab.research.google.com/github/ETKalon/SUAI_EduPrac/blob/main/Laba1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Список
# 1. Первый
# 2. Второй
# 3. Третий

# %% [markdown]
# ## Рисунок
# ![Rayan.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Таблица
#
# | Номер Пары | Предмет | Преподаватель |
# | ------- | -------- | --------|
# | 1 | Учебная Практика | Е.А. Фролов |
# | 2 | Метематический анализ | А.О. Смирнов |

# %% [markdown]
# ## Ссылка
# https://guap.ru/m/ens
